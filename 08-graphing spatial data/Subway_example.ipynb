# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
df_subway_entrances = pd.read_csv("Subway_Entrances/subway_entrances.csv")

# %%
df_subway_entrances.head()
# Out:
#            X          Y                                               name  \
# 0 -73.990272  40.686728  Smith St & Bergen St At Ne Corner (To Manhatta...
# 1 -73.990678  40.693725                Court St & Montague St At Sw Corner
# 2 -73.990592  40.693642                Court St & Montague St At Sw Corner
# 3 -73.992537  40.694393              Clinton St & Montague St At Nw Corner
# 4 -73.962249  40.662727            Flatbush Ave & Empire Blvd At Sw Corner
#
#           line                                url
# 0          F-G  http://www.mta.info/nyct/service/
# 1  2-3-4-5-N-R  http://www.mta.info/nyct/service/
# 2  2-3-4-5-N-R  http://www.mta.info/nyct/service/
# 3  2-3-4-5-N-R  http://www.mta.info/nyct/service/
# 4        B-Q-S  http://www.mta.info/nyct/service/

# %%
df_census_areas = pd.read_csv("tl_2013_36_tract/census_data_areas.csv")

# %%
df_census_areas.head()
# Out:
#    STATEFP  COUNTYFP  TRACTCE        GEOID    NAME             NAMELSAD  \
# 0       36        93    33102  36093033102  331.02  Census Tract 331.02
# 1       36        93    20102  36093020102  201.02  Census Tract 201.02
# 2       36        93    32504  36093032504  325.04  Census Tract 325.04
# 3       36        81     3400  36081003400   34.00      Census Tract 34
# 4       36        81     3900  36081003900   39.00      Census Tract 39
#
#    MTFCC FUNCSTAT      ALAND   AWATER   INTPTLAT   INTPTLON
# 0  G5020        S  183329989  3232878  42.777998 -74.172702
# 1  G5020        S     854904        0  42.829538 -73.916141
# 2  G5020        S   66000589  1265253  42.901052 -74.028893
# 3  G5020        S     213984        0  40.684773 -73.858187
# 4  G5020        S     146970        0  40.762799 -73.940932

# %%
df_census_areas = pd.read_csv("subways_median_income.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-c1453fef9eab> in <module>()
# ----> 1 df_census_areas = pd.read_csv("subways_median_income.csv")
#
# ...

# %%
df_census_areas.head()
# Out:
#    STATEFP  COUNTYFP  TRACTCE        GEOID    NAME             NAMELSAD  \
# 0       36        93    33102  36093033102  331.02  Census Tract 331.02
# 1       36        93    20102  36093020102  201.02  Census Tract 201.02
# 2       36        93    32504  36093032504  325.04  Census Tract 325.04
# 3       36        81     3400  36081003400   34.00      Census Tract 34
# 4       36        81     3900  36081003900   39.00      Census Tract 39
#
#    MTFCC FUNCSTAT      ALAND   AWATER   INTPTLAT   INTPTLON
# 0  G5020        S  183329989  3232878  42.777998 -74.172702
# 1  G5020        S     854904        0  42.829538 -73.916141
# 2  G5020        S   66000589  1265253  42.901052 -74.028893
# 3  G5020        S     213984        0  40.684773 -73.858187
# 4  G5020        S     146970        0  40.762799 -73.940932

# %%
df_census_areas[df_census_areas['line'].str.contains('D')].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'line'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e94badad888f> in <module>()
# ...

# %%
df_census_areas[df_census_areas['line'].str.contains('D')].plot(kind='barh', x='name', y='median_income')

# %%
subway_exits = df[df['line'].str.contains('D')]

# %%
subway_exits.plot(kind='barh', x='')

# %%
df_census_areas = pd.read_csv("median_income_D_line.csv")

# %%
df_census_areas.head(1)
# Out:
#    cartodb_id                                           the_geom  \
# 0           6  0101000020E6100000883818EEEF7E52C0795E4F52AD56...
#
#                                  url  \
# 0  http://www.mta.info/nyct/service/
#
#                                                 name   line  median_income
# 0  4th Ave & Union St At Sw Corner (To Bay Ridge ...  D-N-R        82500.0

# %%
df_census_areas['name'].drop_duplicates(keep='first')
# Out:
# 0      4th Ave & Union St At Sw Corner (To Bay Ridge ...
# 1      4th Ave & Union St At Se Corner (To Manhattan ...
# 3                   Flatbush Ave & Fleet St At Ne Corner
# 4                      4th Ave & Pacific St At Nw Corner
# 5                    Ashland Pl & Hanson Pl At Ne Corner
# 6                                         1550 71 Street
# 7                Flatbush Ave & De Kalb Ave At Se Corner
# 8                                         4902 12 Avenue
# 9                                           956 8 Avenue
# 10                                         1824 Broadway
# 11                        4th Ave & 10th St At Nw Corner
# 12                        6th Ave & 32nd St At Nw Corner
# 13                       Broadway & 34th St At Nw Corner
# 14                       Broadway & 32nd St At Ne Corner
# 15                        6th Ave & 35th St At Nw Corner
# 16                        6th Ave & 40th St At Nw Corner
# ...

# %%
df_census_areas['median_income'].drop_duplicates(keep='first')
# Out:
# 0       82500.0
# 1      132768.0
# 3       90993.0
# 4      104728.0
# 5       60435.0
# 6       43000.0
# 7       98472.0
# 8       30000.0
# 9      128969.0
# 10     162576.0
# 11      81875.0
# 12     143750.0
# 13     132500.0
# 14      90417.0
# 16      81786.0
# 17     126250.0
# 19      28824.0
# 20      91875.0
# 21      82296.0
# 22      38708.0
# 25     104940.0
# 26      43965.0
# 27      56563.0
# 28      87813.0
# 29      30515.0
# 30     107875.0
# 33      30142.0
# 35      43942.0
# 48      44333.0
# 49      44263.0
#          ...
# 103     36481.0
# 104     22318.0
# 106     32127.0
# 108     40151.0
# 113     29457.0
# 115     74813.0
# 116     36921.0
# 127    144097.0
# 137     48243.0
# 138     79345.0
# 141    122500.0
# 143     88988.0
# 145     12479.0
# 147     37719.0
# 155     39219.0
# 163     38618.0
# 174     22233.0
# 176     31309.0
# 177     45465.0
# 178     29000.0
# 181     24612.0
# 184     37045.0
# 188     35392.0
# 191     77898.0
# ...

# %%
df_census_areas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 6 columns):
# cartodb_id       224 non-null int64
# the_geom         224 non-null object
# url              224 non-null object
# name             224 non-null object
# line             224 non-null object
# median_income    223 non-null float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.6+ KB

# %%
df_D = df_census_areas[df_census_areas['line'] == 'D']

# %%
df_D = df_D.drop_duplicates(keep='first')

# %%
df_D['median_income_dup'] = df_D['median_income'].drop_duplicates(keep='first')

# %%
df_D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 6 to 188
# Data columns (total 7 columns):
# cartodb_id           45 non-null int64
# the_geom             45 non-null object
# url                  45 non-null object
# name                 45 non-null object
# line                 45 non-null object
# median_income        45 non-null float64
# median_income_dup    20 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.8+ KB

# %%
df_D.head(5)
# Out:
#     cartodb_id                                           the_geom  \
# 6          424  0101000020E610000063938690F37F52C0AC04E145394F...
# 8           39  0101000020E6100000A2BF16B9A77F52C03BA736BF7451...
# 18         365  0101000020E6100000966C82FFAD7F52C0BFC624716951...
# 22         379  0101000020E61000007F222F4F0A8052C09701BD039D4E...
# 23         382  0101000020E6100000C0AC301F108052C0B1E9B6FE704E...
#
#                                   url            name line  median_income  \
# 6   http://www.mta.info/nyct/service/  1550 71 Street    D        43000.0
# 8   http://www.mta.info/nyct/service/  4902 12 Avenue    D        30000.0
# 18  http://www.mta.info/nyct/service/  1173 50 Street    D        30000.0
# 22  http://www.mta.info/nyct/service/  1654 77 Street    D        38708.0
# 23  http://www.mta.info/nyct/service/  1673 79 Street    D        38708.0
#
#     median_income_dup
# 6             43000.0
# 8             30000.0
# 18                NaN
# 22            38708.0
# ...

# %%
df_D.plot(kind='barh', x='name', y='median_income_dup', figsize=(7,20))

# %%
df_D = df_D['median_income'].drop_duplicates(keep='first')

# %%
df_D
# Out:
# 6      43000.0
# 8      30000.0
# 22     38708.0
# 27     56563.0
# 29     30515.0
# 33     30142.0
# 48     44333.0
# 49     44263.0
# 50     45696.0
# 51     40428.0
# 52     49435.0
# 54     37105.0
# 58     26327.0
# 59     29814.0
# 61     57500.0
# 64     47552.0
# 65     51363.0
# 108    40151.0
# 163    38618.0
# 188    35392.0
# Name: median_income, dtype: float64
